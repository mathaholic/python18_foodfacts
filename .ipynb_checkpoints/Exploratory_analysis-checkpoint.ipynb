# %%
import sys
print(sys.version)
import numpy as np
print(np.__version__)
import pandas as pd
print(pd.__version__)
import matplotlib.pyplot as plt
import re
# Out:
# 3.5.2 |Anaconda 4.1.1 (x86_64)| (default, Jul  2 2016, 17:52:12)
# [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]
# 1.11.1
# 0.18.1

# %%
df = pd.read_csv("openfoodfacts_search.csv", sep = '\t')
df.head()
# Out:
#             code                                                url  \
# 0  5010092093045  http://world.openfoodfacts.org/product/5010092...
# 1    44000030377  http://world.openfoodfacts.org/product/0044000...
# 2        7832309    http://world.openfoodfacts.org/product/07832309
# 3  5099353000169  http://world.openfoodfacts.org/product/5099353...
# 4    82592720153  http://world.openfoodfacts.org/product/0082592...
#
#                       creator   created_t  last_modified_t  \
# 0                    bcatelin  1389309305       1461479010
# 1  openfoodfacts-contributors  1385850411       1459174448
# 2  openfoodfacts-contributors  1403210081       1458995984
# 3                    bcatelin  1385926289       1413659845
# 4  openfoodfacts-contributors  1389308826       1459174499
#
#            product_name generic_name              quantity    packaging  \
# 0            Soft white  White bread                  800g  Plastic bag
# 1  Wheat Thins Original          NaN                  258g          NaN
# 2        Diet Dr Pepper          NaN                   NaN          can
# 3                  Eggs         Eggs                     6      Cardbox
# 4         Green Machine          NaN  15.2 fl. oz (450 mL)          NaN
#
#   packaging_tags           ...           caffeine_100g taurine_100g ph_100g  \
# 0    plastic-bag           ...                     NaN          NaN     NaN
# 1            NaN           ...                     NaN          NaN     NaN
# 2            can           ...                     NaN          NaN     NaN
# 3        cardbox           ...                     NaN          NaN     NaN
# 4            NaN           ...                     NaN          NaN     NaN
#
#   fruits-vegetables-nuts_100g collagen-meat-protein-ratio_100g cocoa_100g  \
# 0                         NaN                              NaN        NaN
# 1                         NaN                              NaN        NaN
# 2                         NaN                              NaN        NaN
# 3                         NaN                              NaN        NaN
# 4                         NaN                              NaN        NaN
#
#   chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0             NaN                 125.0                    -1.0
# 1             NaN                   NaN                     NaN
# 2             NaN                   NaN                     NaN
# 3             NaN                   NaN                     NaN
# 4             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g
# 0                    -1.0
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 150 columns]

# %%
###it apppears that pandas is truncating some data.  let's change that
pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#             code                                                   url  \
# 0  5010092093045  http://world.openfoodfacts.org/product/5010092093045
# 1  44000030377    http://world.openfoodfacts.org/product/0044000030377
# 2  7832309        http://world.openfoodfacts.org/product/07832309
# 3  5099353000169  http://world.openfoodfacts.org/product/5099353000169
# 4  82592720153    http://world.openfoodfacts.org/product/0082592720153
#
#                       creator   created_t  last_modified_t  \
# 0  bcatelin                    1389309305  1461479010
# 1  openfoodfacts-contributors  1385850411  1459174448
# 2  openfoodfacts-contributors  1403210081  1458995984
# 3  bcatelin                    1385926289  1413659845
# 4  openfoodfacts-contributors  1389308826  1459174499
#
#            product_name generic_name              quantity    packaging  \
# 0  Soft white            White bread  800g                  Plastic bag
# 1  Wheat Thins Original  NaN          258g                  NaN
# 2  Diet Dr Pepper        NaN          NaN                   can
# 3  Eggs                  Eggs         6                     Cardbox
# 4  Green Machine         NaN          15.2 fl. oz (450 mL)  NaN
#
#   packaging_tags           ...           caffeine_100g taurine_100g ph_100g  \
# 0  plastic-bag             ...           NaN           NaN          NaN
# 1  NaN                     ...           NaN           NaN          NaN
# 2  can                     ...           NaN           NaN          NaN
# 3  cardbox                 ...           NaN           NaN          NaN
# 4  NaN                     ...           NaN           NaN          NaN
#
#   fruits-vegetables-nuts_100g collagen-meat-protein-ratio_100g cocoa_100g  \
# 0 NaN                         NaN                              NaN
# 1 NaN                         NaN                              NaN
# 2 NaN                         NaN                              NaN
# 3 NaN                         NaN                              NaN
# 4 NaN                         NaN                              NaN
#
#   chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0 NaN              125.0                -1.0
# 1 NaN             NaN                   NaN
# 2 NaN             NaN                   NaN
# 3 NaN             NaN                   NaN
# 4 NaN             NaN                   NaN
#
#   nutrition-score-uk_100g
# 0 -1.0
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 150 columns]

# %%
list(df.columns)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'last_modified_t',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'labels',
#  'labels_tags',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'emb_codes',
#  'emb_codes_tags',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'ingredients_text',
#  'allergens',
#  'allergens_tags',
#  'traces',
#  'traces_tags',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil',
#  'ingredients_that_may_be_from_palm_oil_tags',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'main_category',
#  'image_url',
#  'image_small_url',
#  'image_front_url',
#  'image_front_small_url',
#  'image_ingredients_url',
#  'image_ingredients_small_url',
#  'image_nutrition_url',
#  'image_nutrition_small_url',
#  'energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  '-butyric-acid_100g',
#  '-caproic-acid_100g',
#  '-caprylic-acid_100g',
#  '-capric-acid_100g',
#  '-lauric-acid_100g',
#  '-myristic-acid_100g',
#  '-palmitic-acid_100g',
#  '-stearic-acid_100g',
#  '-arachidic-acid_100g',
#  '-behenic-acid_100g',
#  '-lignoceric-acid_100g',
#  '-cerotic-acid_100g',
#  '-montanic-acid_100g',
#  '-melissic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  '-alpha-linolenic-acid_100g',
#  '-eicosapentaenoic-acid_100g',
#  '-docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  '-linoleic-acid_100g',
#  '-arachidonic-acid_100g',
#  '-gamma-linolenic-acid_100g',
#  '-dihomo-gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  '-oleic-acid_100g',
#  '-elaidic-acid_100g',
#  '-gondoic-acid_100g',
#  '-mead-acid_100g',
#  '-erucic-acid_100g',
#  '-nervonic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  '-sucrose_100g',
#  '-glucose_100g',
#  '-fructose_100g',
#  '-lactose_100g',
#  '-maltose_100g',
#  '-maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'chlorophyl_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g']

# %%
df['energy_100g'].head()
# Out:
# 0    1007.0
# 1   NaN
# 2   NaN
# 3   NaN
# 4    244.0
# Name: energy_100g, dtype: float64

# %%
df['carbohydrates_100g'].head()
# Out:
# 0    44.6
# 1   NaN
# 2   NaN
# 3   NaN
# 4    13.8
# Name: carbohydrates_100g, dtype: float64

# %%
df['carbohydrates_100g'].count()
# Out:
# 1292

# %%
df['fat_100g'].count()
# Out:
# 1295

# %%
df['proteins_100g'].count()
# Out:
# 1284

# %%
df['energy_100g'].count()
# Out:
# 1283

# %%
###verify the nutrition facts add up with the manufacturer's data
### it appears from the site's documentation that 
###http://world.openfoodfacts.org/data/data-fields.txt
###[nutrient]_100gr is nutrients per 100gr or mL
###step 1, grab data for an identifable product

df[['code', 'url', 'product_name', 'energy_100g','carbohydrates_100g', 
    'fat_100g', 'proteins_100g','serving_size']].iloc[20]
# Out:
# code                  36632036506
# url                   http://world.openfoodfacts.org/product/0036632036506
# product_name          Activia light blueberry
# energy_100g           222
# carbohydrates_100g    9.73
# fat_100g              0
# proteins_100g         3.54
# serving_size          1 container (113g)
# Name: 20, dtype: object

# %%
#step 2: verify the data on the site's own product page
import html5lib
site = 'http://www.activia.us.com/probiotic-yogurt/products/activia-light-blueberry'
blueberry_yougurt = pd.read_html(site)[0].set_index('Nutritional Facts')
blueberry_yougurt
# Out:
#                    per serving (113g) Calories from Fat
# Nutritional Facts
# NaN                 NaN                % Daily Value*
# Calories            60                 0
# Total Fat           0g                 0%
# Saturated Fat       0g                 0%
# Trans Fat           0g                 NaN
# Cholesterol         <5mg               1%
# Sodium              65mg               3%
# Potassium           200mg              6%
# Total Carbohydrate  11g                4%
# Dietary Fiber       2g                 8%
# Sugars              7g                 NaN
# Protein             4g                 8%
# Vitamin A           NaN                0%
# Vitamin C           NaN                0%
# Calcium             NaN                15%
# Iron                NaN                0%

# %%
### the calroies(energy) does not look like it is 220 cals/100gr, but the carb/protein/fat ratio looks about right
### verify the macronutrients per 100gr are equivalent to the food facts db:
print(float(blueberry_yougurt.loc['Protein'][0].strip('g'))/1.13)
print(float(blueberry_yougurt.loc['Total Carbohydrate'][0].strip('g'))/1.13)
print(float(blueberry_yougurt.loc['Total Fat'][0].strip('g'))/1.13)
# Out:
# 3.5398230088495577
# 9.734513274336283
# 0.0

# %%
###the total macronutrients per 100 grams posted in the food facts db roughly matches what is posted on the product's
###own site.  Let's check anoother product, this time at random:
np.random.seed(4)
df[['code', 'url', 'product_name', 'energy_100g','carbohydrates_100g', 
    'fat_100g', 'proteins_100g','serving_size']].iloc[np.random.randint(0,len(df))]
# Out:
# code                  27000379097
# url                   http://world.openfoodfacts.org/product/0027000379097
# product_name          Crushed tomatoes
# energy_100g           155
# carbohydrates_100g    7.44
# fat_100g              0
# proteins_100g         1.65
# serving_size          121 g
# Name: 1146, dtype: object

# %%
site = 'http://www.hunts.com/nutrition-label?upc=2700037909&inline=false'
hunts_tomatoes = pd.read_html(site)
#hunts_tomatoes = pd.read_html(site)[1].set_index('Nutrition Facts')
hunts_tomatoes[1][0]
# Out:
# 0     Nutrition Facts
# 1     Serving Size  1/2 cup (121g)
# 2     Servings Per Container about 7
# 3     NaN
# 4     Amount Per Serving
# 5     Calories 45Calories from Fat 0
# 6     NaN
# 7     NaN
# 8     Total Fat 0g
# 9     NaN
# 10    NaN
# 11    Cholesterol 0mg
# 12    Sodium 210mg
# 13    Potassium 370mg
# 14    Total Carbohydrate 9g
# 15    NaN
# 16    NaN
# 17    Protein 2g
# Name: 0, dtype: object

# %%
###this product's label isn't as nicely formattted, but we can get some information from it
#per 121 grams, there are 0 grams of fat, 9 gr of carbohydrate, and 2 gr of protein
carbs_per_100g = 9/1.21
protein_per_100g = 2/1.21
cals_per_100gr = 45/1.21
print('carbs: ',carbs_per_100g, 'protein: ', protein_per_100g, 'cals: ', cals_per_100gr)
# Out:
# carbs:  7.43801652892562 protein:  1.6528925619834711 cals:  37.1900826446281

# %%
###again, we have parity except with the energy field.  
### it would make the most sense to add in a new calculated field that looks at total calories per 100 gr.
###Calories is a function of the macro nutrients and can be found using basic algebra
### cals = 9*fat + 4* protein + 4*carbohydrates + 7*alcohol
###  let's add in the correctd calories per 100 grams
def cals(w, x, y):
    return (9*w) + (4*(x + y))

df['calories_100g'] = np.vectorize(cals)(df['fat_100g'], df['proteins_100g'], df['carbohydrates_100g'])

# %%
#verify against a known product:
df[['code', 'url', 'product_name', 'energy_100g','carbohydrates_100g', 
    'fat_100g', 'proteins_100g','serving_size', 'calories_100g']].iloc[20]
# Out:
# code                  36632036506
# url                   http://world.openfoodfacts.org/product/0036632036506
# product_name          Activia light blueberry
# energy_100g           222
# carbohydrates_100g    9.73
# fat_100g              0
# proteins_100g         3.54
# serving_size          1 container (113g)
# calories_100g         53.08
# Name: 20, dtype: object

# %%
df['calories_100g'].iloc[20]*1.13
# Out:
# 59.980399999999996

# %%
###This value is nearly identical to the value listed for 113 grams on activia's website
###it is safe to use this calorie value in place of the energy_100g field
df.head()
# Out:
#             code                                                   url  \
# 0  5010092093045  http://world.openfoodfacts.org/product/5010092093045
# 1  44000030377    http://world.openfoodfacts.org/product/0044000030377
# 2  7832309        http://world.openfoodfacts.org/product/07832309
# 3  5099353000169  http://world.openfoodfacts.org/product/5099353000169
# 4  82592720153    http://world.openfoodfacts.org/product/0082592720153
#
#                       creator   created_t  last_modified_t  \
# 0  bcatelin                    1389309305  1461479010
# 1  openfoodfacts-contributors  1385850411  1459174448
# 2  openfoodfacts-contributors  1403210081  1458995984
# 3  bcatelin                    1385926289  1413659845
# 4  openfoodfacts-contributors  1389308826  1459174499
#
#            product_name generic_name              quantity    packaging  \
# 0  Soft white            White bread  800g                  Plastic bag
# 1  Wheat Thins Original  NaN          258g                  NaN
# 2  Diet Dr Pepper        NaN          NaN                   can
# 3  Eggs                  Eggs         6                     Cardbox
# 4  Green Machine         NaN          15.2 fl. oz (450 mL)  NaN
#
#   packaging_tags      ...      taurine_100g ph_100g  \
# 0  plastic-bag        ...      NaN          NaN
# 1  NaN                ...      NaN          NaN
# 2  can                ...      NaN          NaN
# 3  cardbox            ...      NaN          NaN
# 4  NaN                ...      NaN          NaN
#
#   fruits-vegetables-nuts_100g collagen-meat-protein-ratio_100g cocoa_100g  \
# 0 NaN                         NaN                              NaN
# 1 NaN                         NaN                              NaN
# 2 NaN                         NaN                              NaN
# 3 NaN                         NaN                              NaN
# 4 NaN                         NaN                              NaN
#
#   chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0 NaN              125.0                -1.0
# 1 NaN             NaN                   NaN
# 2 NaN             NaN                   NaN
# 3 NaN             NaN                   NaN
# 4 NaN             NaN                   NaN
#
#   nutrition-score-uk_100g calories_100g
# 0 -1.0                     232.400
# 1 NaN                     NaN
# 2 NaN                     NaN
# 3 NaN                     NaN
# 4 NaN                      58.532
#
# [5 rows x 151 columns]

# %%
df['calories_100g'].describe()
# Out:
# /Users/nicholeh/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1270.000000
# mean     289.772217
# std      201.152261
# min      0.000000
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max      900.000000
# Name: calories_100g, dtype: float64

# %%
df['proteins_100g'].describe()
# Out:
# /Users/nicholeh/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1284.000000
# mean     6.568091
# std      7.565550
# min      0.000000
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max      70.000000
# Name: proteins_100g, dtype: float64

# %%
df['fat_100g'].describe()
# Out:
# /Users/nicholeh/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1295.000000
# mean     13.589666
# std      18.440903
# min      0.000000
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max      100.000000
# Name: fat_100g, dtype: float64

# %%
df['carbohydrates_100g'].describe()
# Out:
# /Users/nicholeh/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1292.000000
# mean     35.559534
# std      30.094423
# min      0.000000
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max      120.000000
# Name: carbohydrates_100g, dtype: float64

# %%
###save the df with the new calories
df.to_csv('groomed_food_facts_data.cs', sep = '\t')

# %%
###according to the source material, the following score gives information the total nutritive value of a 
###product
###nutrition-score-uk_100g
###from the Food Standards Administration:
###A food is classified as 'less healthy' where it scores 4 points or more.
###A drink is classified as 'less healthy' where it scores 1 point or more. 
###so, a product's score is like golf; the lower the better
###The score  can be verified using the information on this site:
###http://www.food.gov.uk/sites/default/files/multimedia/pdfs/techguidenutprofiling.pdf
df['nutrition-score-uk_100g'].describe()
# Out:
# /Users/nicholeh/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1110.000000
# mean     8.779279
# std      9.420778
# min     -10.000000
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max      29.000000
# Name: nutrition-score-uk_100g, dtype: float64

# %%
###let's check to see if a score exits for the yogurt example
#verify against a known product:
df[['code', 'url', 'product_name', 'energy_100g','carbohydrates_100g', 
    'fat_100g', 'proteins_100g','serving_size', 'calories_100g', 'nutrition-score-uk_100g']].iloc[20]
# Out:
# code                       36632036506
# url                        http://world.openfoodfacts.org/product/0036632036506
# product_name               Activia light blueberry
# energy_100g                222
# carbohydrates_100g         9.73
# fat_100g                   0
# proteins_100g              3.54
# serving_size               1 container (113g)
# calories_100g              53.08
# nutrition-score-uk_100g   -3
# Name: 20, dtype: object

# %%
#investiate quantity; does quantity contain information of servings per unit or total size of unit?
df['quantity'].head(20)
df['quantity'].value_counts()
# Out:
# 1                                      60
# 16 oz                                  17
# 12 oz                                  16
# 16 fl oz                               15
# 12 fl oz                               14
# 12 oz (340 g)                          14
# 8 oz                                   13
# 6 oz (170 g)                           11
# 8 oz (227 g)                           11
# 3.75 oz (106 g)                        11
# 15 oz (425 g)                          11
# 1 LB (454 g)                           10
# 12 OZ (340 g)                          10
# 7 oz (198 g)                           10
# 6 oz                                   10
# 2 L                                    9
# 100 g                                  9
# 10 oz                                  8
# 1 lb                                   8
# 750 ML                                 8
# 1 gallon (3.78 L)                      8
# 750 ml                                 7
# 1 serving                              7
# 5 oz (142 g)                           7
# 500 ml                                 7
# 450g                                   7
# 340 g                                  7
# 3 oz (85 g)                            7
# 3.5 OZ (100g)                          7
# 300g                                   6
#                                       ..
# 258g                                   1
# 2.25 oz (64 g)                         1
# 14 oz (466 g)                          1
# 10 fl ounce, 295 ml                    1
# 4.4 OZ (125g)                          1
# 5 fl. oz (148 mL)                      1
# 1.58 kg                                1
# 3 lbs                                  1
# 24 - 7/16 FL OZ                        1
# 1.89 l.                                1
# 188 g                                  1
# 6.35oz, 180g (15 pieces)               1
# 14.4 oz                                1
# 24 OZ (680g)                           1
# 1 LB (481 g)                           1
# 14 OZ (396 g)                          1
# 6 cans of 3.75 oz (6 x 106 g) 636 g    1
# 59 fl. oz (1.8 qt) 1.75 L              1
# 64 fl. oz (2 qt) 1.89 L                1
# 6.5 fl oz                              1
# 21 OZ (1 LB 5 OZ) 595g                 1
# 4.60 OZ (129 g)                        1
# 284 g                                  1
# 9 OZ (255 g)                           1
# 312 g                                  1
# 24 FL. Oz. (710 ml)                    1
# 18 oz, 510g                            1
# 368 g                                  1
# 2cups                                  1
# 13 oz (368.5)                          1
# Name: quantity, dtype: int64

# %%
#investiate categories
df['categories'].value_counts()
# Out:
# Sugary snacks,Biscuits and cakes,Biscuits,Cookies                                                                                                         27
# Plant-based foods and beverages,Plant-based foods,Cereals and potatoes,Cereals and their products,Pastas                                                  24
# Sugary snacks,Confectioneries,Candies                                                                                                                     20
# Plant-based foods and beverages,Plant-based foods,Breakfasts,Cereals and potatoes,Cereals and their products,Breakfast cereals                            20
# Groceries,Sauces,Tomato sauces,Ketchup                                                                                                                    15
# Plant-based foods and beverages,Plant-based foods,Cereals and potatoes,Cereals and their products,Noodles,Instant noodles                                 14
# Salty snacks,Appetizers,Crackers                                                                                                                          13
# Dairies,Milks                                                                                                                                             13
# Crackers                                                                                                                                                  13
# Beverages,Alcoholic beverages,Beers                                                                                                                       12
# Groceries,Sauces,Mayonnaises                                                                                                                              12
# Snacks                                                                                                                                                    11
# Groceries,Condiments,Sauces,Mustards                                                                                                                      11
# Groceries,Sauces,Pasta sauces                                                                                                                             11
# Dairies,Cheeses                                                                                                                                           10
# Sugary snacks,Chocolates,Dark chocolates                                                                                                                  10
# Beers                                                                                                                                                     10
# Sugary snacks,Bars                                                                                                                                        9
# Dairies,Yogurts                                                                                                                                           9
# pasta                                                                                                                                                     9
# Dairies,Yogurts,Greek yogurts                                                                                                                             9
# Beverages,Waters,Non-sugared beverages                                                                                                                    9
# water                                                                                                                                                     8
# Cheese                                                                                                                                                    8
# Breakfast cereals                                                                                                                                         8
# Sugary snacks,Biscuits and cakes,Biscuits,Cookies,Chocolate cookies                                                                                       8
# Groceries,Sauces                                                                                                                                          8
# Canned foods,Seafood,Fishes,Canned fishes,Sardines,Canned sardines                                                                                        7
# Dairies,Yogurts,Low-fat yogurts                                                                                                                           7
# Candies                                                                                                                                                   7
#                                                                                                                                                          ..
# Whole wheat tortillas,tortillas,wheat tortillas                                                                                                           1
# Beverages,Carbonated drinks,Artificially sweetened beverages,Sodas,Diet beverages,Diet sodas,Colas,Non-sugared beverages                                  1
# cherry tomatoes                                                                                                                                           1
# honey                                                                                                                                                     1
# Strawberry topping                                                                                                                                        1
# Corn Tortilla Chips                                                                                                                                       1
# Farming products,Eggs,Grade A eggs                                                                                                                        1
# en:plant-based-foods-and-beverages,en:plant-based-foods,en:groceries,en:condiments,en:spices,en:chili-peppers                                                                                                                                      1
# en:plant-based-foods-and-beverages,en:beverages,en:plant-based-foods,en:groceries,en:condiments,en:culinary-plants,en:hot-beverages,en:aromatic-plants,en:herbal-teas,en:aromatic-herbs,en:non-sugared-beverages,en:rosemary                       1
# en:abricots-secs,en:aliments-d-origine-vegetale,en:aliments-et-boissons-a-base-de-vegetaux,en:aliments-a-base-de-fruits-et-de-legumes,en:aliments-a-base-de-plantes-seches,en:fruits-et-produits-derives,en:fruits-secs,en:produits-deshydrates    1
# en:dairies,en:milks,en:fat-free-milk                                                                                                                                                                                                               1
# en:canned-foods,en:seafood,en:fishes,en:canned-fishes,en:sardines,en:canned-sardines,en:sardines-in-oil                                                                                                                                            1
# en:rice-candy                                                                                                                                                                                                                                      1
# en:plant-based-foods-and-beverages,en:plant-based-foods                                                                                                                                                                                            1
# en:beverages,en:plant-based-beverages,en:fruit-based-beverages,en:juices-and-nectars,en:fruit-juices-and-nectars,en:fruit-juices,en:lemon-juice,en:lemon-juice-from-concentrate,en:non-alcoholic-beverages                                         1
# en:groceries,en:sauces,en:egg-free-mayonnaises,en:mayonnaises                                                                                                                                                                                      1
# en:pickles                                                                                                                                                                                                                                         1
# en:plant-based-foods-and-beverages,en:plant-based-foods,en:fruits-and-vegetables-based-foods,en:fruits-based-foods,en:fruits,en:peaches,en:sliced-peaches                                                                                          1
# en:plant-based-foods-and-beverages,en:plant-based-foods,en:cereals-and-potatoes,en:cereals-and-their-products,en:fats,en:vegetable-fats,en:vegetable-oils,en:cereal-oils,en:corn-oils,en:oils                                                      1
# Name: categories_tags, dtype: int64

# %%
###how often are the categories present?
df[df['categories']!= np.nan]['categories'].count()
# Out:
# 1695

# %%
#subset the data to only include rows with macronutrients and categories
df.head()
# Out:
#             code                                                   url  \
# 0  5010092093045  http://world.openfoodfacts.org/product/5010092093045
# 1  44000030377    http://world.openfoodfacts.org/product/0044000030377
# 2  7832309        http://world.openfoodfacts.org/product/07832309
# 3  5099353000169  http://world.openfoodfacts.org/product/5099353000169
# 4  82592720153    http://world.openfoodfacts.org/product/0082592720153
#
#                       creator   created_t  last_modified_t  \
# 0  bcatelin                    1389309305  1461479010
# 1  openfoodfacts-contributors  1385850411  1459174448
# 2  openfoodfacts-contributors  1403210081  1458995984
# 3  bcatelin                    1385926289  1413659845
# 4  openfoodfacts-contributors  1389308826  1459174499
#
#            product_name generic_name              quantity    packaging  \
# 0  Soft white            White bread  800g                  Plastic bag
# 1  Wheat Thins Original  NaN          258g                  NaN
# 2  Diet Dr Pepper        NaN          NaN                   can
# 3  Eggs                  Eggs         6                     Cardbox
# 4  Green Machine         NaN          15.2 fl. oz (450 mL)  NaN
#
#   packaging_tags      ...      taurine_100g ph_100g  \
# 0  plastic-bag        ...      NaN          NaN
# 1  NaN                ...      NaN          NaN
# 2  can                ...      NaN          NaN
# 3  cardbox            ...      NaN          NaN
# 4  NaN                ...      NaN          NaN
#
#   fruits-vegetables-nuts_100g collagen-meat-protein-ratio_100g cocoa_100g  \
# 0 NaN                         NaN                              NaN
# 1 NaN                         NaN                              NaN
# 2 NaN                         NaN                              NaN
# 3 NaN                         NaN                              NaN
# 4 NaN                         NaN                              NaN
#
#   chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0 NaN              125.0                -1.0
# 1 NaN             NaN                   NaN
# 2 NaN             NaN                   NaN
# 3 NaN             NaN                   NaN
# 4 NaN             NaN                   NaN
#
#   nutrition-score-uk_100g calories_100g
# 0 -1.0                     232.400
# 1 NaN                     NaN
# 2 NaN                     NaN
# 3 NaN                     NaN
# 4 NaN                      58.532
#
# [5 rows x 151 columns]

# %%
list(df.columns)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'last_modified_t',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'labels',
#  'labels_tags',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'emb_codes',
#  'emb_codes_tags',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'ingredients_text',
#  'allergens',
#  'allergens_tags',
#  'traces',
#  'traces_tags',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil',
#  'ingredients_that_may_be_from_palm_oil_tags',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'main_category',
#  'image_url',
#  'image_small_url',
#  'image_front_url',
#  'image_front_small_url',
#  'image_ingredients_url',
#  'image_ingredients_small_url',
#  'image_nutrition_url',
#  'image_nutrition_small_url',
#  'energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  '-butyric-acid_100g',
#  '-caproic-acid_100g',
#  '-caprylic-acid_100g',
#  '-capric-acid_100g',
#  '-lauric-acid_100g',
#  '-myristic-acid_100g',
#  '-palmitic-acid_100g',
#  '-stearic-acid_100g',
#  '-arachidic-acid_100g',
#  '-behenic-acid_100g',
#  '-lignoceric-acid_100g',
#  '-cerotic-acid_100g',
#  '-montanic-acid_100g',
#  '-melissic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  '-alpha-linolenic-acid_100g',
#  '-eicosapentaenoic-acid_100g',
#  '-docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  '-linoleic-acid_100g',
#  '-arachidonic-acid_100g',
#  '-gamma-linolenic-acid_100g',
#  '-dihomo-gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  '-oleic-acid_100g',
#  '-elaidic-acid_100g',
#  '-gondoic-acid_100g',
#  '-mead-acid_100g',
#  '-erucic-acid_100g',
#  '-nervonic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  '-sucrose_100g',
#  '-glucose_100g',
#  '-fructose_100g',
#  '-lactose_100g',
#  '-maltose_100g',
#  '-maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'chlorophyl_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g',
#  'calories_100g']

# %%
### Parse down to important data:
keep_cols = ['code', 'product_name', 'generic_name','categories','categories_tags', 'ingredients_text','main_category',
            'fat_100g', 'saturated-fat_100g','monounsaturated-fat_100g', 'polyunsaturated-fat_100g','omega-3-fat_100g',
            'omega-6-fat_100g', 'omega-9-fat_100g', 'cholesterol_100g', 'carbohydrates_100g', 'sugars_100g','fiber_100g',
            'proteins_100g','salt_100g', 'sodium_100g', 'alcohol_100g', 'vitamin-a_100g','vitamin-c_100g','potassium_100g',
             'chloride_100g', 'calcium_100g', 'iron_100g', 'fruits-vegetables-nuts_100g', 'nutrition-score-uk_100g', 'calories_100g'
            ]

df_keep = df[keep_cols]
df_keep = df_keep.dropna(subset=['calories_100g'])

# %%
df_keep.reset_index(inplace=True)

# %%
del df_keep['index']
df_keep.head(15)
# Out:
#              code                     product_name  \
# 0   5010092093045  Soft white
# 1   82592720153    Green Machine
# 2   9800895250     Nutella
# 3   71443003903    NaN
# 4   36632036506    Activia light blueberry
# 5   4154891        Almond Milk Unsweetened
# 6   41570054130    Almond Milk Unsweetened
# 7   41735020000    Apple Cider Vinegar
# 8   28400183901    Baked Cheetos
# 9   78742143330    Blueberry Lowfat Yogurt
# 10  41449003153    Buttermilk complete pancake mix
# 11  51000000118    Campbell Tomato Soup
# 12  4002468021319  Cheddar
# 13  871459000220   Cheddar Cheese Slices
# 14  3077601        Chewy
#
#                               generic_name  \
# 0   White bread
# 1   NaN
# 2   Hazelnut spread with skim milk & cacao
# 3   NaN
# 4   Yaourt
# 5   Unsweetened almond milk
# 6   Unsweetened almond milk
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11
# 12  en:cheeses                                     17.000
# 13  en:cheeses                                     4.500
# 14  en:peanut-butter-and-chocolat-chip-cereal-bar  12.500
#
#     saturated-fat_100g  monounsaturated-fat_100g      ...        alcohol_100g  \
# 0   0.300              NaN                            ...       NaN
# 1  NaN                 NaN                            ...       NaN
# 2   10.800             NaN                            ...       NaN
# 3   5.950              NaN                            ...       NaN
# 4   0.000              NaN                            ...       NaN
# 5   0.000              NaN                            ...       NaN
# 6   0.000              NaN                            ...       NaN
# 7  NaN                 NaN                            ...       NaN
# 8   3.570              NaN                            ...       NaN
# 9   0.588              NaN                            ...       NaN
# 10  1.000              NaN                            ...       NaN
# 11  0.000               0.0                           ...       NaN
# 12 NaN                 NaN                            ...       NaN
# 13  2.000              NaN                            ...       NaN
# 14  0.000              NaN                            ...       NaN
#
#     vitamin-a_100g  vitamin-c_100g  potassium_100g  chloride_100g  \
# 0  NaN             NaN             NaN             NaN
# 1   0.000313        0.010           0.1670         NaN
# 2   0.000000        0.000          NaN             NaN
# 3  NaN             NaN             NaN             NaN
# 4  NaN             NaN              0.1770         NaN
# 5   0.000063        0.000           0.0708         NaN
# 6   0.000063        0.000           0.0708         NaN
# 7  NaN             NaN             NaN             NaN
# 8   0.000000        0.000           0.2140         NaN
# 9  NaN             NaN              0.1350         NaN
# 10  0.000000        0.000          NaN             NaN
# 11  0.000100        0.005           0.5750         NaN
# 12 NaN             NaN             NaN             NaN
# 13 NaN             NaN             NaN             NaN
# 14 NaN             NaN             NaN             NaN
#
#     calcium_100g  iron_100g  fruits-vegetables-nuts_100g  \
# 0  NaN           NaN        NaN
# 1   0.00833       0.000300  NaN
# 2   0.10800       0.001950  NaN
# 3  NaN            0.000857  NaN
# 4   0.13300      NaN        NaN
# 5   0.18800       0.000300  NaN
# 6   0.18800       0.000300  NaN
# 7  NaN           NaN        NaN
# 8   0.35700       0.009640  NaN
# 9  NaN           NaN        NaN
# 10  0.08000       0.003600  NaN
# 11  0.00000       0.000600  NaN
# 12 NaN           NaN        NaN
# 13 NaN           NaN        NaN
# 14 NaN           NaN        NaN
#
#     nutrition-score-uk_100g  calories_100g
# 0  -1.0                      232.400
# 1  NaN                       58.532
# 2   23.0                     540.440
# 3   16.0                     400.000
# 4  -3.0                      53.080
# 5   0.0                      14.360
# 6   0.0                      14.360
# 7  NaN                       0.000
# 8   12.0                     475.260
# 9   3.0                      88.098
# 10  14.0                     355.000
# 11  4.0                      73.480
# 12 NaN                       241.000
# 13 NaN                       64.500
# 14  15.0                     445.700
#
# [15 rows x 31 columns]

# %%
### df_keep constitutes our dataset, let's save it off

df_keep.to_csv('valid_entries.tsv', sep = '\t')

# %%
### now, let's create a random sampling for 10,000 days.
### each day will have 20 - 100 gram servings randomly selected from the df_keep set.  It will start with aggregate
### showing the total calories, carbs, fat, protein, and major vitamims.
### next, there will be a micronutrient_complete column that will have a Boolean value of True or False.  If the 
### micronutrient_complete column is False, we will know that for that day, our vitamin/mineral numbers may not be 
### complete.
